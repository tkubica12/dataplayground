# %% [markdown]
# # Interactive debug and coding notebook
#
# In order to write Python code to be used as job it is sometimes slow to iterate while waiting for job output. In order to quickly come with working code we can load data interactively and play with code before we make it separate file.filter

# %%
# AzureML workspace details:
subscription = 'd3b7888f-c26e-4961-a976-ff9d5b31dfd3'
resource_group = 'data-demo-azureml'
workspace = 'itckftsmsixv'
datastore_name = 'workspaceblobstore'
path_on_datastore = 'creditcard_cli'

# long-form Datastore uri format:
uri = f'azureml://subscriptions/{subscription}/resourcegroups/{resource_group}/workspaces/{workspace}/datastores/{datastore_name}/paths/{path_on_datastore}'

# %%
# !pip install -U azureml-fsspec mltable
# Out:
# ...
#      |████████████████████████████████| 149 kB 8.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 43.5 MB 96.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 16.4 MB 91.2 MB/s eta 0:00:01
# ...
# ERROR: azureml-dataset-runtime 1.47.0 has requirement azureml-dataprep<4.6.0a,>=4.5.0a, but you'll have azureml-dataprep 4.8.3 which is incompatible.
# ERROR: azureml-automl-runtime 1.47.0 has requirement protobuf<=3.20.1, but you'll have protobuf 4.21.11 which is incompatible.
# ...
#   Attempting uninstall: azureml-dataprep-rslex
#     Found existing installation: azureml-dataprep-rslex 2.11.4
#     Uninstalling azureml-dataprep-rslex-2.11.4:
#       Successfully uninstalled azureml-dataprep-rslex-2.11.4
#   Attempting uninstall: azureml-dataprep
#     Found existing installation: azureml-dataprep 4.5.7
#     Uninstalling azureml-dataprep-4.5.7:
#       Successfully uninstalled azureml-dataprep-4.5.7
# ...

# %%
import pandas as pd

df = pd.read_csv(uri)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [7], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(uri)
#       4 df.head()
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pandas/io/parsers.py:688, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     635     engine_specified = False
# ...
